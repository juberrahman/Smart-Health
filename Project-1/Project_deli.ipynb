# %%
## Get necessary imports
## Darshan Pai - Project 1
import numpy as np
import os
import shutil
import posixpath
import wfdb
import biosppy

# %%
## Download all the WFDB records from Physionet
cwd = os.getcwd()
dl_dir = os.path.join(cwd, "tmp_dl_dir")

wfdb.dl_database('apnea-ecg', dl_dir=dl_dir)

display(os.listdir(dl_dir))
# Out:
# Generating record list for: a01
# Generating record list for: a01er
# Generating record list for: a01r
# Generating record list for: a02
# Generating record list for: a02er
# Generating record list for: a02r
# Generating record list for: a03
# Generating record list for: a03er
# Generating record list for: a03r
# Generating record list for: a04
# Generating record list for: a04er
# Generating record list for: a04r
# Generating record list for: a05
# Generating record list for: a06
# Generating record list for: a07
# Generating record list for: a08
# Generating record list for: a09
# Generating record list for: a10
# Generating record list for: a11
# Generating record list for: a12
# Generating record list for: a13
# Generating record list for: a14
# Generating record list for: a15
# Generating record list for: a16
# Generating record list for: a17
# Generating record list for: a18
# Generating record list for: a19
# Generating record list for: a20
# Generating record list for: b01
# Generating record list for: b01er
# Generating record list for: b01r
# Generating record list for: b02
# Generating record list for: b03
# Generating record list for: b04
# Generating record list for: b05
# Generating record list for: c01
# Generating record list for: c01er
# Generating record list for: c01r
# Generating record list for: c02
# Generating record list for: c02er
# Generating record list for: c02r
# Generating record list for: c03
# Generating record list for: c03er
# Generating record list for: c03r
# Generating record list for: c04
# Generating record list for: c05
# Generating record list for: c06
# Generating record list for: c07
# Generating record list for: c08
# Generating record list for: c09
# Generating record list for: c10
# Generating record list for: x01
# Generating record list for: x02
# Generating record list for: x03
# Generating record list for: x04
# Generating record list for: x05
# Generating record list for: x06
# Generating record list for: x07
# Generating record list for: x08
# Generating record list for: x09
# Generating record list for: x10
# Generating record list for: x11
# Generating record list for: x12
# Generating record list for: x13
# Generating record list for: x14
# Generating record list for: x15
# Generating record list for: x16
# Generating record list for: x17
# Generating record list for: x18
# Generating record list for: x19
# Generating record list for: x20
# Generating record list for: x21
# Generating record list for: x22
# Generating record list for: x23
# Generating record list for: x24
# Generating record list for: x25
# Generating record list for: x26
# Generating record list for: x27
# Generating record list for: x28
# Generating record list for: x29
# Generating record list for: x30
# Generating record list for: x31
# Generating record list for: x32
# Generating record list for: x33
# Generating record list for: x34
# Generating record list for: x35
# Generating list of all files for: a01
# Generating list of all files for: a01er
# Generating list of all files for: a01r
# Generating list of all files for: a02
# Generating list of all files for: a02er
# Generating list of all files for: a02r
# Generating list of all files for: a03
# Generating list of all files for: a03er
# Generating list of all files for: a03r
# Generating list of all files for: a04
# Generating list of all files for: a04er
# Generating list of all files for: a04r
# Generating list of all files for: a05
# Generating list of all files for: a06
# Generating list of all files for: a07
# Generating list of all files for: a08
# Generating list of all files for: a09
# Generating list of all files for: a10
# Generating list of all files for: a11
# Generating list of all files for: a12
# Generating list of all files for: a13
# Generating list of all files for: a14
# Generating list of all files for: a15
# Generating list of all files for: a16
# Generating list of all files for: a17
# Generating list of all files for: a18
# Generating list of all files for: a19
# Generating list of all files for: a20
# Generating list of all files for: b01
# Generating list of all files for: b01er
# Generating list of all files for: b01r
# Generating list of all files for: b02
# Generating list of all files for: b03
# Generating list of all files for: b04
# Generating list of all files for: b05
# Generating list of all files for: c01
# Generating list of all files for: c01er
# Generating list of all files for: c01r
# Generating list of all files for: c02
# Generating list of all files for: c02er
# Generating list of all files for: c02r
# Generating list of all files for: c03
# Generating list of all files for: c03er
# Generating list of all files for: c03r
# Generating list of all files for: c04
# Generating list of all files for: c05
# Generating list of all files for: c06
# Generating list of all files for: c07
# Generating list of all files for: c08
# Generating list of all files for: c09
# Generating list of all files for: c10
# Generating list of all files for: x01
# Generating list of all files for: x02
# Generating list of all files for: x03
# Generating list of all files for: x04
# Generating list of all files for: x05
# Generating list of all files for: x06
# Generating list of all files for: x07
# Generating list of all files for: x08
# Generating list of all files for: x09
# Generating list of all files for: x10
# Generating list of all files for: x11
# Generating list of all files for: x12
# Generating list of all files for: x13
# Generating list of all files for: x14
# Generating list of all files for: x15
# Generating list of all files for: x16
# Generating list of all files for: x17
# Generating list of all files for: x18
# Generating list of all files for: x19
# Generating list of all files for: x20
# Generating list of all files for: x21
# Generating list of all files for: x22
# Generating list of all files for: x23
# Generating list of all files for: x24
# Generating list of all files for: x25
# Generating list of all files for: x26
# Generating list of all files for: x27
# Generating list of all files for: x28
# Generating list of all files for: x29
# Generating list of all files for: x30
# Generating list of all files for: x31
# Generating list of all files for: x32
# Generating list of all files for: x33
# Generating list of all files for: x34
# Generating list of all files for: x35
# Created local base download directory: c:\Workspace\Practice\Python\MLSH_projects\tmp_dl_dir
# Downloading files...
# Finished downloading files
# ['a01.apn',
#  'a01.dat',
#  'a01.hea',
#  'a01.qrs',
#  'a01er.apn',
#  'a01er.hea',
#  'a01er.qrs',
#  'a01r.apn',
#  'a01r.dat',
#  'a01r.hea',
#  'a02.apn',
#  'a02.dat',
#  'a02.hea',
#  'a02.qrs',
#  'a02er.apn',
#  'a02er.hea',
#  'a02er.qrs',
#  'a02r.apn',
#  'a02r.dat',
#  'a02r.hea',
#  'a03.apn',
#  'a03.dat',
#  'a03.hea',
#  'a03.qrs',
#  'a03er.apn',
#  'a03er.hea',
#  'a03er.qrs',
#  'a03r.apn',
#  'a03r.dat',
#  'a03r.hea',
#  'a04.apn',
#  'a04.dat',
#  'a04.hea',
#  'a04.qrs',
#  'a04er.apn',
#  'a04er.hea',
#  'a04er.qrs',
#  'a04r.apn',
#  'a04r.dat',
#  'a04r.hea',
#  'a05.apn',
#  'a05.dat',
#  'a05.hea',
#  'a05.qrs',
#  'a06.apn',
#  'a06.dat',
#  'a06.hea',
#  'a06.qrs',
#  'a07.apn',
#  'a07.dat',
#  'a07.hea',
#  'a07.qrs',
#  'a08.apn',
#  'a08.dat',
#  'a08.hea',
#  'a08.qrs',
#  'a09.apn',
#  'a09.dat',
#  'a09.hea',
#  'a09.qrs',
#  'a10.apn',
#  'a10.dat',
#  'a10.hea',
#  'a10.qrs',
#  'a11.apn',
#  'a11.dat',
#  'a11.hea',
#  'a11.qrs',
#  'a12.apn',
#  'a12.dat',
#  'a12.hea',
#  'a12.qrs',
#  'a13.apn',
#  'a13.dat',
#  'a13.hea',
#  'a13.qrs',
#  'a14.apn',
#  'a14.dat',
#  'a14.hea',
#  'a14.qrs',
#  'a15.apn',
#  'a15.dat',
#  'a15.hea',
#  'a15.qrs',
#  'a16.apn',
#  'a16.dat',
#  'a16.hea',
#  'a16.qrs',
#  'a17.apn',
#  'a17.dat',
#  'a17.hea',
#  'a17.qrs',
#  'a18.apn',
#  'a18.dat',
#  'a18.hea',
#  'a18.qrs',
#  'a19.apn',
#  'a19.dat',
#  'a19.hea',
#  'a19.qrs',
#  'a20.apn',
#  'a20.dat',
#  'a20.hea',
#  'a20.qrs',
#  'b01.apn',
#  'b01.dat',
#  'b01.hea',
#  'b01.qrs',
#  'b01er.apn',
#  'b01er.hea',
#  'b01er.qrs',
#  'b01r.apn',
#  'b01r.dat',
#  'b01r.hea',
#  'b02.apn',
#  'b02.dat',
#  'b02.hea',
#  'b02.qrs',
#  'b03.apn',
#  'b03.dat',
#  'b03.hea',
#  'b03.qrs',
#  'b04.apn',
#  'b04.dat',
#  'b04.hea',
#  'b04.qrs',
#  'b05.apn',
#  'b05.dat',
#  'b05.hea',
#  'b05.qrs',
#  'c01.apn',
#  'c01.dat',
#  'c01.hea',
#  'c01.qrs',
#  'c01er.apn',
#  'c01er.hea',
#  'c01er.qrs',
#  'c01r.apn',
#  'c01r.dat',
#  'c01r.hea',
#  'c02.apn',
#  'c02.dat',
#  'c02.hea',
#  'c02.qrs',
#  'c02er.apn',
#  'c02er.hea',
#  'c02er.qrs',
#  'c02r.apn',
#  'c02r.dat',
#  'c02r.hea',
#  'c03.apn',
#  'c03.dat',
#  'c03.hea',
#  'c03.qrs',
#  'c03er.apn',
#  'c03er.hea',
#  'c03er.qrs',
#  'c03r.apn',
#  'c03r.dat',
#  'c03r.hea',
#  'c04.apn',
#  'c04.dat',
#  'c04.hea',
#  'c04.qrs',
#  'c05.apn',
#  'c05.dat',
#  'c05.hea',
#  'c05.qrs',
#  'c06.apn',
#  'c06.dat',
#  'c06.hea',
#  'c06.qrs',
#  'c07.apn',
#  'c07.dat',
#  'c07.hea',
#  'c07.qrs',
#  'c08.apn',
#  'c08.dat',
#  'c08.hea',
#  'c08.qrs',
#  'c09.apn',
#  'c09.dat',
#  'c09.hea',
#  'c09.qrs',
#  'c10.apn',
#  'c10.dat',
#  'c10.hea',
#  'c10.qrs',
#  'x01.apn',
#  'x01.dat',
#  'x01.hea',
#  'x01.qrs',
#  'x02.apn',
#  'x02.dat',
#  'x02.hea',
#  'x02.qrs',
#  'x03.apn',
#  'x03.dat',
#  'x03.hea',
#  'x03.qrs',
#  'x04.apn',
#  'x04.dat',
#  'x04.hea',
#  'x04.qrs',
#  'x05.apn',
#  'x05.dat',
#  'x05.hea',
#  'x05.qrs',
#  'x06.apn',
#  'x06.dat',
#  'x06.hea',
#  'x06.qrs',
#  'x07.apn',
#  'x07.dat',
#  'x07.hea',
#  'x07.qrs',
#  'x08.apn',
#  'x08.dat',
#  'x08.hea',
#  'x08.qrs',
#  'x09.apn',
#  'x09.dat',
#  'x09.hea',
#  'x09.qrs',
#  'x10.apn',
#  'x10.dat',
#  'x10.hea',
#  'x10.qrs',
#  'x11.apn',
#  'x11.dat',
#  'x11.hea',
#  'x11.qrs',
#  'x12.apn',
#  'x12.dat',
#  'x12.hea',
#  'x12.qrs',
#  'x13.apn',
#  'x13.dat',
#  'x13.hea',
#  'x13.qrs',
#  'x14.apn',
#  'x14.dat',
#  'x14.hea',
#  'x14.qrs',
#  'x15.apn',
#  'x15.dat',
#  'x15.hea',
#  'x15.qrs',
#  'x16.apn',
#  'x16.dat',
#  'x16.hea',
#  'x16.qrs',
#  'x17.apn',
#  'x17.dat',
#  'x17.hea',
#  'x17.qrs',
#  'x18.apn',
#  'x18.dat',
#  'x18.hea',
#  'x18.qrs',
#  'x19.apn',
#  'x19.dat',
#  'x19.hea',
#  'x19.qrs',
#  'x20.apn',
#  'x20.dat',
#  'x20.hea',
#  'x20.qrs',
#  'x21.apn',
#  'x21.dat',
#  'x21.hea',
#  'x21.qrs',
#  'x22.apn',
#  'x22.dat',
#  'x22.hea',
#  'x22.qrs',
#  'x23.apn',
#  'x23.dat',
#  'x23.hea',
#  'x23.qrs',
#  'x24.apn',
#  'x24.dat',
#  'x24.hea',
#  'x24.qrs',
#  'x25.apn',
#  'x25.dat',
#  'x25.hea',
#  'x25.qrs',
#  'x26.apn',
#  'x26.dat',
#  'x26.hea',
#  'x26.qrs',
#  'x27.apn',
#  'x27.dat',
#  'x27.hea',
#  'x27.qrs',
#  'x28.apn',
#  'x28.dat',
#  'x28.hea',
#  'x28.qrs',
#  'x29.apn',
#  'x29.dat',
#  'x29.hea',
#  'x29.qrs',
#  'x30.apn',
#  'x30.dat',
#  'x30.hea',
#  'x30.qrs',
#  'x31.apn',
#  'x31.dat',
#  'x31.hea',
#  'x31.qrs',
#  'x32.apn',
#  'x32.dat',
#  'x32.hea',
#  'x32.qrs',
#  'x33.apn',
#  'x33.dat',
#  'x33.hea',
#  'x33.qrs',
#  'x34.apn',
#  'x34.dat',
#  'x34.hea',
#  'x34.qrs',
#  'x35.apn',
#  'x35.dat',
#  'x35.hea',
#  'x35.qrs']

# %%
## For each record process and append to the csv file
from hrvanalysis import remove_ectopic_beats, interpolate_nan_values, get_time_domain_features, get_frequency_domain_features, get_geometrical_features
from hrvanalysis import get_csi_cvi_features, get_poincare_plot_features 
import csv

csv_file = "features.csv"
enter = False

for root, directories, files in os.walk(dl_dir, topdown=False):
	with open('Annotations.txt', newline = '') as names:
		name_reader = csv.reader(names, delimiter='\t')
		for name in name_reader:
			#print(name)
			full_p = os.path.join(root, name[0])
			#print(full_p)
			record = wfdb.rdrecord(full_p, sampfrom=0, sampto=100000)
			ind = biosppy.signals.ecg.ecg(record.p_signal[:,0], sampling_rate=100, show=False)
			rr_ind = np.diff(ind['rpeaks'])
			rr_ms = [element * 10 for element in rr_ind]
			ect_ind = remove_ectopic_beats(rr_ms)
			nn_interval = interpolate_nan_values(rr_intervals=ect_ind)
			time_dict = get_time_domain_features(nn_interval)
			results = {}
			results['avnn'] = time_dict['mean_nni']
			results['hr'] = time_dict['mean_hr']
			results['SDNN'] = time_dict['sdnn']
			results['pNN50'] = time_dict['pnni_20']
			results['RMSSD'] = time_dict['rmssd']
			results['HRdiff'] = time_dict['max_hr'] - time_dict['min_hr']
			freq_dict = get_frequency_domain_features(nn_interval)

			results['VLF'] = freq_dict['vlf']
			results['LF'] = freq_dict['lf']
			results['HF'] = freq_dict['hf']
			results['LHFratio'] = freq_dict['lf_hf_ratio']
			results['record']=name[0]
			results['length-min']=name[1]
			results['non-apn-min']=name[2]
			results['apn-min']=name[3]
			results['hours-apn']=name[4]
			results['AI']=name[5]
			results['HI']=name[6]
			results['AHI']=name[7]
			results['Age']=name[8]
			results['Sex']=name[9]
			results['height']=name[10]
			results['weight']=name[11]
			print(results)
			csv_columns = results.keys()
			with open(csv_file, 'a', newline='') as csvfile:
				writer = csv.DictWriter(csvfile, fieldnames=csv_columns) 
				if enter == False:
					writer.writeheader()
					enter = True
				writer.writerow(results)
# Out:
# 10 ectopic beat(s) have been deleted with malik rule.
# {'avnn': 831.5137614678899, 'hr': 73.04062883477803, 'SDNN': 90.6995053435377, 'pNN50': 47.24540901502504, 'RMSSD': 43.32246985099053, 'HRdiff': 45.45454545454545, 'VLF': 1253.0659317695213, 'LF': 1672.2046668444693, 'HF': 663.069710839543, 'LHFratio': 2.5219138191777972, 'record': 'a01', 'length-min': '490', 'non-apn-min': '20', 'apn-min': '470', 'hours-apn': '9', 'AI': '12.5', 'HI': '57.1', 'AHI': '69.6', 'Age': '51', 'Sex': 'M', 'height': '175', 'weight': '102'}
# 20 ectopic beat(s) have been deleted with malik rule.
# {'avnn': 755.933484504913, 'hr': 84.55735826708907, 'SDNN': 64.42473324065006, 'pNN50': 9.07715582450832, 'RMSSD': 37.1334837135976, 'HRdiff': 5941.747572815534, 'VLF': 971.5964907559306, 'LF': 772.9338443279158, 'HF': 410.65467891836596, 'LHFratio': 1.882199044617649, 'record': 'a02', 'length-min': '529', 'non-apn-min': '109', 'apn-min': '420', 'hours-apn': '9', 'AI': '57.2', 'HI': '12.3', 'AHI': '69.5', 'Age': '38', 'Sex': 'M', 'height': '180', 'weight': '120'}
# 6 ectopic beat(s) have been deleted with malik rule.
# {'avnn': 17441.346153846152, 'hr': 63.09428159813443, 'SDNN': 101765.23660216463, 'pNN50': 57.28155339805825, 'RMSSD': 84112.24163701669, 'HRdiff': 272.6571095979972, 'VLF': 458993671.8487386, 'LF': 70464312.60738635, 'HF': 6001842.762956534, 'LHFratio': 11.740446291311258, 'record': 'a03', 'length-min': '520', 'non-apn-min': '274', 'apn-min': '246', 'hours-apn': '9', 'AI': '38.4', 'HI': '0.7', 'AHI': '39.1', 'Age': '54', 'Sex': 'M', 'height': '168', 'weight': '80'}
# 17 ectopic beat(s) have been deleted with malik rule.
# {'avnn': 729.2074506939372, 'hr': 82.82723766985511, 'SDNN': 48.53003745197252, 'pNN50': 3.58187134502924, 'RMSSD': 27.266418949674733, 'HRdiff': 163.35350043215212, 'VLF': 443.05179460359454, 'LF': 285.1669592800725, 'HF': 209.10796812786657, 'LHFratio': 1.3637307168787414, 'record': 'a04', 'length-min': '493', 'non-apn-min': '40', 'apn-min': '453', 'hours-apn': '9', 'AI': '73.4', 'HI': '4', 'AHI': '77.4', 'Age': '52', 'Sex': 'M', 'height': '173', 'weight': '121'}
# 2 ectopic beat(s) have been deleted with malik rule.
# {'avnn':
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
## Split Apnea and non-Apnea data
## Load the feature csv file
Data = pd.read_csv('features.csv')
Apnea_data = Data[Data.AHI>4]
NonApnea_data = Data[Data.AHI<=4]

# %%
print(f"Number of datasets with Apnea {len(Apnea_data)}")
print(f"Number of datasets that do not have Apnea {len(NonApnea_data)}")
# Out:
# Number of datasets with Apnea 47
# Number of datasets that do not have Apnea 23

# %%
## Plot as a bar chart
# %matplotlib inline 
categories = ['Apnea', 'NonApnea']
counts = [len(Apnea_data), len(NonApnea_data)]

fig, ax = plt.subplots()
x_pos = np.arange(len(categories))
plt.bar(x_pos, counts, align='center', alpha=0.5)
ax.set_ylabel('Frequency')
ax.set_xticks(x_pos)
ax.set_xticklabels(categories)
ax.set_title('Number of patients in each category')
ax.yaxis.grid(True)


# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot.png')
plt.show()

# %%
## Proportion of men and women in the 2 categories
print(f"Proportion of men within the Apnea class is {len(Apnea_data[Apnea_data.Sex == 'M'])/len(Apnea_data)}")
print(f"Proportion of men within the Non Apnea class is {len(NonApnea_data[NonApnea_data.Sex == 'M'])/len(NonApnea_data)}")
# Out:
# Proportion of men within the Apnea class is 0.9574468085106383
# Proportion of men within the Non Apnea class is 0.5217391304347826

# %%
# Pie charts showing the proportions based on sex
males_Apnea = (len(Apnea_data[Apnea_data.Sex == 'M'])/len(Apnea_data))*100
males_nonApnea = (len(NonApnea_data[NonApnea_data.Sex == 'M'])/len(NonApnea_data))*100
sizes_Apnea = [males_Apnea, 100-males_Apnea]
sizes_NonApnea = [males_nonApnea, 100-males_nonApnea]

colors = ['#66b3ff', '#ff9999']

fig, ax = plt.subplots(1,2)
ax[0].pie(sizes_Apnea, labels=['Male', 'Female'], autopct='%1.1f%%', colors = colors, textprops={'color':"w"})
ax[0].axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax[0].set_title('Apnea patients', color='white')

ax[1].pie(sizes_NonApnea, labels=['Male', 'Female'], autopct='%1.1f%%',  colors = colors, textprops={'color':"w"})
ax[1].axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
ax[1].set_title('Non Apnea patients', color='white')
fig.suptitle("Male/Female ratio", color='white')

plt.show()

# %%
## Age Distribution
n_bins = 5
fig, axs = plt.subplots(1, 2, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
axs[0].hist(Apnea_data.Age, bins=n_bins)
axs[0].set_title('Apnea patients')
axs[1].hist(NonApnea_data.Age, bins=n_bins)
axs[1].set_title('Non Apnea patients')
fig.suptitle("Age Distribution")
# Out:
# Text(0.5, 0.98, 'Age Distribution')

# %%
Data['Target'] = np.where(Data['AHI']>4,'A','H')
print(len(Data[Data.Target=='A']))
# Out:
# 47

# %%
## Save the data for Weka
Data.to_csv('ApneaDataSet.csv', index=False)

# %%
fig2, ax2 = plt.subplots(2,5)
fig2.suptitle("Box Plot of HRV features (Apnea) vs (Healthy)")
fig2.set_size_inches(18.5, 10.5)

for i,el in enumerate(list(Data.columns.values)[:10]):
    a = Data.boxplot(el, by="Target", ax=ax2.flatten()[i], showfliers=False)

# %%
Apnea_data.describe()
# Out:
#                avnn          hr           SDNN      pNN50         RMSSD  \
# 25%     302.848412  2.812509e+03  2.804487e+03  1.889035e+03   1.585038
# 50%     595.759717  9.031529e+05  1.998206e+05  1.418373e+04   5.578502
# 75%     665.956434  3.417645e+07  1.080738e+06  1.088584e+05  10.256517
# max    5999.716727  7.093625e+07  1.011680e+07  1.813533e+06  22.498659
#
#        length-min  non-apn-min    apn-min  hours-apn         AI         HI  \
# count   23.000000    23.000000  23.000000  23.000000  23.000000  23.000000
# mean   467.347826   464.478261   2.869565   0.173913   0.063478   0.016087
# std     27.659634    28.181021   4.683669   0.491026   0.163752   0.056788
# min    401.000000   400.000000   0.000000   0.000000   0.000000   0.000000
# 25%    454.500000   452.500000   0.000000   0.000000   0.000000   0.000000
# 50%    469.000000   468.000000   1.000000   0.000000   0.000000   0.000000
# 75%    483.000000   482.000000   3.000000   0.000000   0.000000   0.000000
# max    535.000000   535.000000  19.000000   2.000000   0.700000   0.250000
#
#              AHI        Age      height     weight
# count  23.000000  23.000000   23.000000  23.000000
# mean    0.079565  34.000000  175.000000  65.260870
# std     0.170919   6.274045    8.257228   8.247409
# min     0.000000  27.000000  158.000000  53.000000
# 25%     0.000000  28.000000  169.500000  60.000000
# 50%     0.000000  31.000000  180.000000  65.000000
# 75%     0.065000  40.000000  182.000000  69.000000
# max     0.700000  44.000000  184.000000  83.000000

# %%
print(f"From just looking at the plots and summary time features SDNN, RMSSD and frequency features HF is more significant")
print(f"This can be seen though the non-parametric test below. Compared with avnn which is not significant")
# Out:
# From just looking at the plots and summary time features SDNN, RMSSD and frequency features HF is more significant
# This can be seen though the non-parametric test below. Compared with avnn which is not significant

# %%
## Using t-test below for the 10 features
from scipy.stats import ttest_ind, ttest_rel, mannwhitneyu

## I think these are dependent samples
ttest_rel(Apnea_data.HF, NonApnea_data.HF)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\212364~1\AppData\Local\Temp/ipykernel_3984/3617184555.py in <module>
#       3
#       4 ## I think these are dependent samples
# ----> 5 ttest_rel(Apnea_data.HF, NonApnea_data.HF)
#
# ~\.virtualenvs\MLSH_projects-OhkKaBlK\lib\site-packages\scipy\stats\stats.py in ttest_rel(a, b, axis, nan_policy, alternative)
#    6443     nb = _get_len(b, axis, "second argument")
#    6444     if na != nb:
# -> 6445         raise ValueError('unequal length arrays')
#    6446
#    6447     if na == 0:
#
# ValueError: unequal length arrays

# %%
U1, p = mannwhitneyu(Apnea_data.HF, NonApnea_data.HF, method="auto")
print(U1,p)
# Out:
# 86.0 1.372287469649795e-08

# %%
U1, p = mannwhitneyu(Apnea_data.RMSSD, NonApnea_data.RMSSD, method="auto")
print(U1,p)
# Out:
# 107.0 6.155387535369218e-08

# %%
U1, p = mannwhitneyu(Apnea_data.SDNN, NonApnea_data.SDNN, method="auto")
print(U1,p)
# Out:
# 114.0 1.0001339683982572e-07

# %%
U1, p = mannwhitneyu(Apnea_data.avnn, NonApnea_data.avnn, method="auto")
print(U1,p)
# Out:
# 449.0 0.25517767321655005

# %%
print(f"Did Machine learning using Weka, used Naive Bayes, Logistic, and Random Forest")
print(f"With a 80% train/test split and CV of 5, each gives 100% accuracy. Logs added")
